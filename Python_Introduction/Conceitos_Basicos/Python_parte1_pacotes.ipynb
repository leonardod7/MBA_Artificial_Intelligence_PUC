# %% [markdown]
# # Pacotes

# %%
# Importações das bibliotecas
from matplotlib import pyplot as plt
import numpy as np

# %%
# gerei amostra com ditribuição normal
amostra = np.random.normal(size=1000)

# %%
plt.hist(amostra, bins=50);

# %%
amostra2 = np.random.uniform(size=1000)

# %%
plt.hist(amostra2, bins=50, color='orange');

# %% [markdown]
# Instalar pacotes

# %%
pip install deap
# Out:
# ...
#      |████████████████████████████████| 163kB 2.8MB/s
# ...

# %%
import deap
